# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
sns.set_context("talk")
plt.rcParams['font.family'] = "Ubuntu"

# %%
df=pd.read_excel('./Files/Facebook Insights Data Export (Post Level) - Volt Danmark - Post insights last 7 days.xlsx', sheet_name='Key Metrics', skiprows=[1], index_col='Date')
df = df.fillna(value=0)
df.index = pd.to_datetime(df.index)
df.color = '#582c83'

# %%
df.head()
# Out:
#             Lifetime Total Likes  Daily New Likes  Daily Unlikes  \
# Date
# 2020-04-27                  1060              0.0            0.0
# 2020-04-28                  1060              0.0            0.0
# 2020-04-29                  1059              0.0            1.0
# 2020-04-30                  1060              1.0            0.0
# 2020-05-01                  1060              1.0            1.0
#
#             Daily Page Engaged Users  Weekly Page Engaged Users  \
# Date
# 2020-04-27                       4.0                         54
# 2020-04-28                       8.0                         50
# 2020-04-29                       8.0                         54
# 2020-04-30                      76.0                        125
# 2020-05-01                       3.0                        119
#
#             28 Days Page Engaged Users  Daily Total Reach  Weekly Total Reach  \
# Date
# 2020-04-27                         255                 98                 571
# ...

# %%
fig, ax = plt.subplots(figsize=(8,4))

df['Lifetime Total Likes'].plot(ax=ax, color='#582c83')

ax.set_title("Total number of page likes", loc='left')
ax.set_ylabel('Likes')
ax.set_xlabel('')

plt.tight_layout()
plt.savefig('./Figures/totalpagelikes.png', dpi=300)

plt.show()

# %% [markdown]
# ---

# %%
fig, ax = plt.subplots(figsize=(8,8), nrows=3, sharex=True)

df['Daily Page Engaged Users'].plot(ax=ax[0], color='#582c83')

ax[0].set_title("Engaged users - click or story", loc='left')
ax[0].set_ylabel('Users')

df['Daily Paid Reach'].plot(ax=ax[1], color='#582c83')
ax[1].set_title('Daily paid reach', loc='left')

df['Daily Total Impressions'].plot(ax=ax[2], color='#582c83')
ax[2].set_title('Daily Total impressions', loc='left')


ax[2].set_xlabel('')

for axe in ax:
    axe.set_ylim(bottom=0)

plt.tight_layout()
plt.subplots_adjust(hspace=0.24)
plt.savefig('./Figures/engagement.png', dpi=300)

plt.show()

# %%
sns.scatterplot(x='Daily Paid Reach', y='Daily Total Impressions', data=df, color='#582c83')
plt.xlim(left=0)
plt.ylim(bottom=0)
plt.tight_layout()
plt.savefig('./Figures/reach.png', dpi=300)
plt.show()
