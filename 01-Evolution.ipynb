# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
sns.set_context("talk")
plt.rcParams['font.family'] = "Ubuntu"

# %%
df = pd.read_excel('./Files/Facebook Insights Data Export - Volt Danmark - 2020-07-12.xlsx',sheet_name='Key Metrics', skiprows=[1], index_col='Data')
df = df.fillna(value=0)
df.index = pd.to_datetime(df.index)
df.color = '#582c83'

# %%
df.head()
# Out:
#             Lifetime Total Likes  Daily New Likes  Daily Unlikes  \
# Data
# 2020-04-14                  1056              0.0            0.0
# 2020-04-15                  1057              1.0            0.0
# 2020-04-16                  1059              2.0            0.0
# 2020-04-17                  1058              0.0            1.0
# 2020-04-18                  1058              0.0            0.0
#
#             Daily Page Engaged Users  Weekly Page Engaged Users  \
# Data
# 2020-04-14                       5.0                         80
# 2020-04-15                      25.0                         92
# 2020-04-16                      28.0                        104
# 2020-04-17                      49.0                        136
# 2020-04-18                      14.0                        140
#
#             28 Days Page Engaged Users  Daily Total Reach  Weekly Total Reach  \
# Data
# 2020-04-14                         209                120                 678
# 2020-04-15                         215                374                 879
# 2020-04-16                         229                259                 985
# 2020-04-17                         259               1485                2252
# 2020-04-18                         269                313                2418
#
#             28 Days Total Reach  Daily Organic Reach  ...  \
# Data                                                  ...
# 2020-04-14                 1466                   68  ...
# 2020-04-15                 1646                  198  ...
# 2020-04-16                 1753                  145  ...
# 2020-04-17                 2976                 1374  ...
# 2020-04-18                 3159                  150  ...
#
#             Daily Total get direction click count per Page.1  \
# Data
# 2020-04-14                                               0.0
# 2020-04-15                                               0.0
# 2020-04-16                                               0.0
# 2020-04-17                                               0.0
# 2020-04-18                                               0.0
#
#             Weekly Total get direction click count per Page.1  \
# Data
# 2020-04-14                                                0.0
# 2020-04-15                                                0.0
# 2020-04-16                                                0.0
# 2020-04-17                                                0.0
# 2020-04-18                                                0.0
#
#             Daily Total phone calls click count per Page  \
# Data
# 2020-04-14                                           0.0
# 2020-04-15                                           0.0
# 2020-04-16                                           0.0
# 2020-04-17                                           0.0
# 2020-04-18                                           0.0
#
#             Weekly Total phone calls click count per Page  \
# Data
# 2020-04-14                                            0.0
# 2020-04-15                                            0.0
# 2020-04-16                                            0.0
# 2020-04-17                                            0.0
# 2020-04-18                                            0.0
#
#             Daily Total phone calls click count per Page.1  \
# Data
# 2020-04-14                                             0.0
# 2020-04-15                                             0.0
# 2020-04-16                                             0.0
# 2020-04-17                                             0.0
# 2020-04-18                                             0.0
#
#             Weekly Total phone calls click count per Page.1  \
# Data
# 2020-04-14                                              0.0
# 2020-04-15                                              0.0
# 2020-04-16                                              0.0
# 2020-04-17                                              0.0
# 2020-04-18                                              0.0
#
#             Daily Total website click count per Page  \
# Data
# 2020-04-14                                       0.0
# 2020-04-15                                       0.0
# 2020-04-16                                       0.0
# 2020-04-17                                       0.0
# 2020-04-18                                       0.0
#
#             Weekly Total website click count per Page  \
# Data
# 2020-04-14                                        0.0
# 2020-04-15                                        0.0
# 2020-04-16                                        0.0
# 2020-04-17                                        0.0
# 2020-04-18                                        0.0
#
#             Daily Total website click count per Page.1  \
# Data
# 2020-04-14                                         0.0
# 2020-04-15                                         0.0
# 2020-04-16                                         0.0
# 2020-04-17                                         0.0
# 2020-04-18                                         0.0
#
#             Weekly Total website click count per Page.1
# Data
# 2020-04-14                                          0.0
# 2020-04-15                                          0.0
# 2020-04-16                                          0.0
# 2020-04-17                                          0.0
# 2020-04-18                                          0.0
#
# [5 rows x 138 columns]

# %%
fig, ax = plt.subplots(figsize=(8,4))

df['Lifetime Total Likes'].plot(ax=ax, color='#582c83')

ax.set_title("Total number of page likes", loc='left')
ax.set_ylabel('Likes')
ax.set_xlabel('')

plt.tight_layout()
plt.savefig('./Figures/totalpagelikes2.png', dpi=300)

plt.show()

# %% [markdown]
# ---

# %%
fig, ax = plt.subplots(figsize=(8,8), nrows=3, sharex=True)

df['Daily Page Engaged Users'].plot(ax=ax[0], color='#582c83')

ax[0].set_title("Engaged users - click or story", loc='left')
ax[0].set_ylabel('Users')

df['Daily Paid Reach'].plot(ax=ax[1], color='#582c83')
ax[1].set_title('Daily paid reach', loc='left')

df['Daily Total Impressions'].plot(ax=ax[2], color='#582c83')
ax[2].set_title('Daily Total impressions', loc='left')


ax[2].set_xlabel('')

for axe in ax:
    axe.set_ylim(bottom=0)

plt.tight_layout()
plt.subplots_adjust(hspace=0.24)
plt.savefig('./Figures/engagement2.png', dpi=300)

plt.show()

# %% [markdown]
# ---

# %%
sns.scatterplot(x='Daily Paid Reach', y='Daily Total Impressions', data=df, color='#582c83')
plt.xlim(left=0)
plt.ylim(bottom=0)
plt.tight_layout()
plt.savefig('./Figures/reach2.png', dpi=300)
plt.show()
