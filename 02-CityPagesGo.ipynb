# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
sns.set_context("talk")
plt.rcParams['font.family'] = "Ubuntu"

# %%
df = pd.read_excel('./Files_II/Facebook Insights Data Export - Volt Danmark - 2020-08-03.xls', sheet_name='Key Metrics', skiprows=[1], index_col='Data')
df = df.fillna(value=0)
df.index = pd.to_datetime(df.index)
df.color = '#582c83'

# %%
df.head()
# Out:
#             Lifetime Total Likes  Daily New Likes  Daily Unlikes  \
# Data
# 2020-04-30                  1060              1.0            0.0
# 2020-05-01                  1060              1.0            1.0
# 2020-05-02                  1060              0.0            0.0
# 2020-05-03                  1060              0.0            0.0
# 2020-05-04                  1060              0.0            0.0
#
#             Daily Page Engaged Users  Weekly Page Engaged Users  \
# Data
# 2020-04-30                      76.0                        125
# 2020-05-01                       3.0                        119
# 2020-05-02                      20.0                        111
# 2020-05-03                      17.0                        109
# 2020-05-04                      16.0                        114
#
#             28 Days Page Engaged Users  Daily Total Reach  Weekly Total Reach  \
# Data
# 2020-04-30                         277                349                 764
# 2020-05-01                         275                 31                 734
# 2020-05-02                         276                205                 599
# 2020-05-03                         277                166                 508
# 2020-05-04                         277                207                 535
#
#             28 Days Total Reach  Daily Organic Reach  ...  \
# Data                                                  ...
# 2020-04-30                 3168                  349  ...
# 2020-05-01                 3145                   29  ...
# 2020-05-02                 3145                  205  ...
# 2020-05-03                 3145                  166  ...
# 2020-05-04                 3201                  207  ...
#
#             Daily Total get direction click count per Page.1  \
# Data
# 2020-04-30                                               0.0
# 2020-05-01                                               0.0
# 2020-05-02                                               0.0
# 2020-05-03                                               0.0
# 2020-05-04                                               0.0
#
#             Weekly Total get direction click count per Page.1  \
# Data
# 2020-04-30                                                0.0
# 2020-05-01                                                0.0
# 2020-05-02                                                0.0
# 2020-05-03                                                0.0
# 2020-05-04                                                0.0
#
#             Daily Total phone calls click count per Page  \
# Data
# 2020-04-30                                           0.0
# 2020-05-01                                           0.0
# 2020-05-02                                           0.0
# 2020-05-03                                           0.0
# 2020-05-04                                           0.0
#
#             Weekly Total phone calls click count per Page  \
# Data
# 2020-04-30                                            0.0
# 2020-05-01                                            0.0
# 2020-05-02                                            0.0
# 2020-05-03                                            0.0
# 2020-05-04                                            0.0
#
#             Daily Total phone calls click count per Page.1  \
# Data
# 2020-04-30                                             0.0
# 2020-05-01                                             0.0
# 2020-05-02                                             0.0
# 2020-05-03                                             0.0
# 2020-05-04                                             0.0
#
#             Weekly Total phone calls click count per Page.1  \
# Data
# 2020-04-30                                              0.0
# 2020-05-01                                              0.0
# 2020-05-02                                              0.0
# 2020-05-03                                              0.0
# 2020-05-04                                              0.0
#
#             Daily Total website click count per Page  \
# Data
# 2020-04-30                                       0.0
# 2020-05-01                                       0.0
# 2020-05-02                                       0.0
# 2020-05-03                                       0.0
# 2020-05-04                                       0.0
#
#             Weekly Total website click count per Page  \
# Data
# 2020-04-30                                        0.0
# 2020-05-01                                        0.0
# 2020-05-02                                        0.0
# 2020-05-03                                        0.0
# 2020-05-04                                        0.0
#
#             Daily Total website click count per Page.1  \
# Data
# 2020-04-30                                         0.0
# 2020-05-01                                         0.0
# 2020-05-02                                         0.0
# 2020-05-03                                         0.0
# 2020-05-04                                         0.0
#
#             Weekly Total website click count per Page.1
# Data
# 2020-04-30                                          0.0
# 2020-05-01                                          0.0
# 2020-05-02                                          0.0
# 2020-05-03                                          0.0
# 2020-05-04                                          0.0
#
# [5 rows x 138 columns]

# %%
fig, ax = plt.subplots(figsize=(8,4))

df['Lifetime Total Likes'].plot(ax=ax, color='#582c83')

ax.set_title("Total number of page likes", loc='left')
ax.set_ylabel('Likes')
ax.set_xlabel('')

plt.tight_layout()
plt.savefig('./Figures/totalpagelikes3.png', dpi=300)

plt.show()

# %% [markdown]
# ---

# %%
fig, ax = plt.subplots(figsize=(8,8), nrows=3, sharex=True)

df['Daily Page Engaged Users'].plot(ax=ax[0], color='#582c83')

ax[0].set_title("Engaged users - click or story", loc='left')
ax[0].set_ylabel('Users')

df['Daily Paid Reach'].plot(ax=ax[1], color='#582c83')
ax[1].set_title('Daily paid reach', loc='left')

df['Daily Total Impressions'].plot(ax=ax[2], color='#582c83')
ax[2].set_title('Daily Total impressions', loc='left')


ax[2].set_xlabel('')

for axe in ax:
    axe.set_ylim(bottom=0)

plt.tight_layout()
plt.subplots_adjust(hspace=0.24)
plt.savefig('./Figures/engagement3.png', dpi=300)

plt.show()
